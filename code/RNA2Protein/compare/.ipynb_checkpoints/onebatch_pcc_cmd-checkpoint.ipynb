# %%
import numpy as np
import pandas as pd
import scanpy as sc
import anndata as ad
from scipy.stats import pearsonr
import matplotlib.pyplot as plt
import seaborn as sns
import argparse
import os

# %%
from scipy.sparse import csr_matrix, coo_matrix, csc_matrix
from scipy.io import mmread, mmwrite

# %%
from scipy import stats

# %%
import seaborn as sns

# %%
import matplotlib

matplotlib.rcParams.update(matplotlib.rcParamsDefault)
# matplotlib.rcParams['pdf.fonttype'] = 42
# matplotlib.rcParams['ps.fonttype'] = 42
# matplotlib.rcParams['font.serif'] = ['Arial']
# # matplotlib.rcParams['font.serif'] = ['SimHei']
# sc.settings.set_figure_params(dpi=150,dpi_save=300,facecolor='white',fontsize=10,figsize=(3,3))
matplotlib.rcParams['font.serif'] = ['Arial']

# %% [markdown]
# # 读取数据 #

# %%
dataset_num = "dataset18_2"

# %%
true_data_path = "/home/qukun/wsy1216/WEDGE/TestData/dataset18_2/adata_test.h5ad"
test_data = sc.read(true_data_path)
true_data = test_data.obsm['protein_expression']
true_data.columns = true_data.columns.str.replace("-","_")
true_data.columns = true_data.columns.str.replace(".","_")
# Out:
# /tmp/ipykernel_6147/4265256342.py:5: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   true_data.columns = true_data.columns.str.replace(".","_")

# %%
totalVI_path = "/home/qukun/wsy1216/WEDGE/Results/totalVI/" + dataset_num + "_batch2_totalVI.csv"
scArches_path = "/home/qukun/wsy1216/WEDGE/Results/scArches/" + dataset_num + "_data_pre_scArches.csv"
Dengkw_path = "/home/qukun/wsy1216/WEDGE/Results/Dengkw/" + dataset_num + "_data_pre_Dengkw.csv"
cTp_net_path = "/home/qukun/wsy1216/WEDGE/Results/cTPnet/" + dataset_num + "_pre_data_cTPnet.csv"
DANCE_path = "/home/qukun/wsy1216/WEDGE/Results/DANCE/" + dataset_num + "_pre_data_dance.csv"
Seurat_path = "/home/qukun/wsy1216/WEDGE/Results/seurat/" + dataset_num + "_pre_data.csv"
Liger_path = "/home/qukun/wsy1216/WEDGE/Results/Liger/Liger_" + dataset_num + "_pre_data.csv"
BABEL_path = "/home/qukun/wsy1216/WEDGE/Results/BABEL_new/" + dataset_num + "_babel_ADT_predict.csv"
CMAE_path = "/home/qukun/wsy1216/WEDGE/Results/CMAE/" + dataset_num + "_cmae_ADT_predict.csv"
sciPENN_path = "/home/qukun/wsy1216/WEDGE/Results/sciPENN/" +dataset_num + "_pre_sciPENN.csv"

# %%
totalVI_pre = pd.read_csv(totalVI_path,index_col = 0)
scArches_pre = pd.read_csv(scArches_path,index_col = 0)
Dengkw_pre = pd.read_csv(Dengkw_path,index_col = 0)
cTp_net_pre = pd.read_csv(cTp_net_path,index_col = 0).T
DANCE_pre = pd.read_csv(DANCE_path,index_col = 0).T
Seurat_pre = pd.read_csv(Seurat_path,index_col = 0).T
Liger_pre = pd.read_csv(Liger_path,index_col = 0).T
BABEL_pre = pd.read_csv(BABEL_path,index_col = 0).T
CMAE_pre = pd.read_csv(CMAE_path,index_col = 0).T
sciPENN_pre = pd.read_csv(sciPENN_path,index_col = 0)

# %%
DANCE_pre = pd.DataFrame(data = DANCE_pre.values, index = true_data.index , columns = true_data.columns)
CMAE_pre = pd.DataFrame(data = CMAE_pre.values, index = true_data.index , columns = true_data.columns)
BABEL_pre = pd.DataFrame(data = BABEL_pre.values, index = true_data.index , columns = true_data.columns)

# %%
totalVI_pre.columns = totalVI_pre.columns.str.replace("-","_")
totalVI_pre.columns = totalVI_pre.columns.str.replace(".","_")
scArches_pre.columns = scArches_pre.columns.str.replace("-","_")
Dengkw_pre.columns = Dengkw_pre.columns.str.replace("-","_")
cTp_net_pre.columns = cTp_net_pre.columns.str.replace("-","_")
Seurat_pre.columns = Seurat_pre.columns.str.replace("-","_")
Seurat_pre.columns = Seurat_pre.columns.str.replace(".","_")
Liger_pre.columns = Liger_pre.columns.str.replace("-","_")
Liger_pre.columns = Liger_pre.columns.str.replace(".","_")
sciPENN_pre.columns = sciPENN_pre.columns.str.replace("-","_")
sciPENN_pre.columns = sciPENN_pre.columns.str.replace(".","_")
# Out:
# /tmp/ipykernel_6147/3522325479.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   totalVI_pre.columns = totalVI_pre.columns.str.replace(".","_")
# /tmp/ipykernel_6147/3522325479.py:8: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Seurat_pre.columns = Seurat_pre.columns.str.replace(".","_")
# /tmp/ipykernel_6147/3522325479.py:10: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Liger_pre.columns = Liger_pre.columns.str.replace(".","_")
# /tmp/ipykernel_6147/3522325479.py:12: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   sciPENN_pre.columns = sciPENN_pre.columns.str.replace(".","_")

# %%
totalVI_pre = totalVI_pre[true_data.columns]
scArches_pre = scArches_pre[true_data.columns]
Dengkw_pre = Dengkw_pre[true_data.columns]
cTp_net_pre = cTp_net_pre[true_data.columns]
DANCE_pre = DANCE_pre[true_data.columns]
Seurat_pre = Seurat_pre[true_data.columns]
Liger_pre = Liger_pre[true_data.columns]
BABEL_pre = BABEL_pre[true_data.columns]
CMAE_pre = CMAE_pre[true_data.columns]
sciPENN_pre = sciPENN_pre[true_data.columns]

# %% [markdown]
# # 计算pccs #

# %% [markdown]
# ### totalVI结果 ###

# %%
totalVI_pcc_protein = []
for i in range(totalVI_pre.shape[1]):
    x = np.array(totalVI_pre[totalVI_pre.columns[i]])
    y = np.array(true_data[true_data.columns[i]])    
    pcc = pearsonr(x,y)[0]
    totalVI_pcc_protein.append(pcc)
totalVI_pcc_cell = []
for i in range(totalVI_pre.shape[0]):
    x = np.array((totalVI_pre.T)[totalVI_pre.index[i]])
    y = np.array((true_data.T)[true_data.index[i]])    
    pcc = pearsonr(x,y)[0]
    totalVI_pcc_cell.append(pcc)

# %% [markdown]
# ### scArches结果 ###

# %%
scArches_pcc_protein = []
for i in range(scArches_pre.shape[1]):
    x = np.array(scArches_pre[scArches_pre.columns[i]])
    y = np.array(true_data[true_data.columns[i]])    
    pcc = pearsonr(x,y)[0]
    scArches_pcc_protein.append(pcc)
scArches_pcc_cell = []
for i in range(scArches_pre.shape[0]):
    x = np.array((scArches_pre.T)[scArches_pre.index[i]])
    y = np.array((true_data.T)[true_data.index[i]])    
    pcc = pearsonr(x,y)[0]
    scArches_pcc_cell.append(pcc)

# %% [markdown]
# ### Dengkw ###

# %%
Dengkw_pcc_protein = []
for i in range(Dengkw_pre.shape[1]):
    x = np.array(Dengkw_pre[Dengkw_pre.columns[i]])
    y = np.array(true_data[true_data.columns[i]])    
    pcc = pearsonr(x,y)[0]
    Dengkw_pcc_protein.append(pcc)
Dengkw_pcc_cell = []
for i in range(Dengkw_pre.shape[0]):
    x = np.array((Dengkw_pre.T)[Dengkw_pre.index[i]])
    y = np.array((true_data.T)[true_data.index[i]])    
    pcc = pearsonr(x,y)[0]
    Dengkw_pcc_cell.append(pcc)

# %% [markdown]
# ### cTp_net ###

# %%
clr_true = true_data.apply(lambda x: np.log((x+1.0)/stats.gmean(x+1.0)), axis=0)

# %%
cTp_net_pcc_protein = []
for i in range(cTp_net_pre.shape[1]):
    x = np.array(cTp_net_pre[cTp_net_pre.columns[i]])
    y = np.array(clr_true[clr_true.columns[i]])    
    pcc = pearsonr(x,y)[0]
    cTp_net_pcc_protein.append(pcc)
cTp_net_pcc_cell = []
for i in range(cTp_net_pre.shape[0]):
    x = np.array((cTp_net_pre.T)[cTp_net_pre.index[i]])
    y = np.array((clr_true.T)[clr_true.index[i]])    
    pcc = pearsonr(x,y)[0]
    cTp_net_pcc_cell.append(pcc)

# %% [markdown]
# ### Dance ###

# %%
DANCE_pcc_protein = []
for i in range(DANCE_pre.shape[1]):
    x = np.array(DANCE_pre[DANCE_pre.columns[i]])
    y = np.array(true_data[true_data.columns[i]])    
    pcc = pearsonr(x,y)[0]
    DANCE_pcc_protein.append(pcc)
DANCE_pcc_cell = []
for i in range(DANCE_pre.shape[0]):
    x = np.array((DANCE_pre.T)[DANCE_pre.index[i]])
    y = np.array((true_data.T)[true_data.index[i]])    
    pcc = pearsonr(x,y)[0]
    DANCE_pcc_cell.append(pcc)

# %% [markdown]
# ### Seurat ###

# %%
clr_true = true_data.apply(lambda x: np.log((x+1.0)/stats.gmean(x+1.0)), axis=0)

# %%
Seurat_pcc_protein = []
for i in range(Seurat_pre.shape[1]):
    x = np.array(Seurat_pre[Seurat_pre.columns[i]])
    y = np.array(clr_true[clr_true.columns[i]])    
    pcc = pearsonr(x,y)[0]
    Seurat_pcc_protein.append(pcc)
Seurat_pcc_cell = []
for i in range(Seurat_pre.shape[0]):
    x = np.array((Seurat_pre.T)[Seurat_pre.index[i]])
    y = np.array((clr_true.T)[clr_true.index[i]])    
    pcc = pearsonr(x,y)[0]
    Seurat_pcc_cell.append(pcc)

# %% [markdown]
# ## Liger ##

# %%
Liger_pcc_protein = []
for i in range(Liger_pre.shape[1]):
    x = np.array(Liger_pre[Liger_pre.columns[i]])
    y = np.array(true_data[true_data.columns[i]])    
    pcc = pearsonr(x,y)[0]
    Liger_pcc_protein.append(pcc)
Liger_pcc_cell = []
for i in range(Liger_pre.shape[0]):
    x = np.array((Liger_pre.T)[Liger_pre.index[i]])
    y = np.array((true_data.T)[true_data.index[i]])    
    pcc = pearsonr(x,y)[0]
    Liger_pcc_cell.append(pcc)
# Out:
# /home/qukun/wsy1216/miniconda3/envs/celleagle/lib/python3.8/site-packages/scipy/stats/_stats_py.py:4068: PearsonRConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(PearsonRConstantInputWarning())

# %% [markdown]
# ### BABEL ###

# %%
BABEL_pcc_protein = []
for i in range(BABEL_pre.shape[1]):
    x = np.array(BABEL_pre[BABEL_pre.columns[i]])
    y = np.array(true_data[true_data.columns[i]])    
    pcc = pearsonr(x,y)[0]
    BABEL_pcc_protein.append(pcc)
BABEL_pcc_cell = []
for i in range(BABEL_pre.shape[0]):
    x = np.array((BABEL_pre.T)[BABEL_pre.index[i]])
    y = np.array((true_data.T)[true_data.index[i]])    
    pcc = pearsonr(x,y)[0]
    BABEL_pcc_cell.append(pcc)

# %% [markdown]
# ## CMAE ##

# %%
CMAE_pcc_protein = []
for i in range(CMAE_pre.shape[1]):
    x = np.array(CMAE_pre[CMAE_pre.columns[i]])
    y = np.array(true_data[true_data.columns[i]])    
    pcc = pearsonr(x,y)[0]
    CMAE_pcc_protein.append(pcc)
CMAE_pcc_cell = []
for i in range(CMAE_pre.shape[0]):
    x = np.array((CMAE_pre.T)[CMAE_pre.index[i]])
    y = np.array((true_data.T)[true_data.index[i]])    
    pcc = pearsonr(x,y)[0]
    CMAE_pcc_cell.append(pcc)

# %% [markdown]
# ## sciPENN

# %%
A = ad.AnnData(X = true_data).copy()
sc.pp.normalize_total(A)
sc.pp.log1p(A)
sc.pp.scale(A)

B = pd.DataFrame(data = A.X,columns = A.var_names,index = A.obs_names)

C = (B.T[sciPENN_pre.index]).T

# %%
sciPENN_scale = ad.AnnData(sciPENN_pre)
sc.pp.scale(sciPENN_scale)
sciPENN_scale = pd.DataFrame(data = sciPENN_scale.X,columns = sciPENN_scale.var_names,index = sciPENN_scale.obs_names)

# %%
sciPENN_pcc_protein = []
for i in range(sciPENN_scale.shape[1]):
    x = np.array(sciPENN_scale[sciPENN_scale.columns[i]])
    y = np.array(C[C.columns[i]])    
    pcc = pearsonr(x,y)[0]
    sciPENN_pcc_protein.append(pcc)
sciPENN_pcc_cell = []
for i in range(sciPENN_scale.shape[0]):
    x = np.array((sciPENN_scale.T)[sciPENN_scale.index[i]])
    y = np.array((C.T)[C.index[i]])    
    pcc = pearsonr(x,y)[0]
    sciPENN_pcc_cell.append(pcc)

# %% [markdown]
# # 综合并绘图 #

# %%
index = ['totalVI','scArches','Dengkw','cTp_net','DANCE','Seurat','Liger','BABEL','CMAE','sciPENN']
pro_columns = true_data.columns
cell_columns = true_data.index
PCCs_protein = pd.DataFrame([totalVI_pcc_protein,scArches_pcc_protein,Dengkw_pcc_protein,cTp_net_pcc_protein,DANCE_pcc_protein,Seurat_pcc_protein,Liger_pcc_protein,BABEL_pcc_protein,CMAE_pcc_protein,sciPENN_pcc_protein],index = index,columns = pro_columns)
PCCs_cell = pd.DataFrame([totalVI_pcc_cell,scArches_pcc_cell,Dengkw_pcc_cell,cTp_net_pcc_cell,DANCE_pcc_cell,Seurat_pcc_cell,Liger_pcc_cell,BABEL_pcc_cell,CMAE_pcc_cell,sciPENN_pcc_cell],index = index,columns = cell_columns)

# %%
PCCs_protein
# Out:
#               CD80      CD86     CD274     CD273   CD275_1   CD11b_1  \
# totalVI   0.147483  0.429244  0.749415  0.002516  0.052420  0.178058
# scArches  0.143838  0.554096  0.716448  0.175283  0.060191  0.041204
# Dengkw    0.039414  0.465607  0.673802  0.077439 -0.013397  0.144378
# cTp_net  -0.151824  0.475393  0.637708 -0.115614 -0.137427 -0.049181
# DANCE     0.225502  0.400421  0.477699  0.169640  0.071906  0.135568
# Seurat    0.158993  0.544845  0.739913  0.122492  0.297743  0.136597
# Liger     0.047192  0.321649  0.398059  0.108381  0.060596  0.128988
# BABEL          NaN  0.200364  0.626821       NaN -0.005807       NaN
# CMAE      0.179125  0.283648  0.420406  0.068156  0.041304  0.033557
# sciPENN   0.034528  0.438917  0.656128  0.109089  0.151502  0.277884
#
#           Galectin_9     CD270     CD252  CD155(PVR)  ...    CD307e     CD319  \
# totalVI     0.044134  0.176190  0.091455   -0.016029  ...  0.662303  0.095144
# scArches    0.072995 -0.019536  0.091175    0.073400  ...  0.630467  0.084462
# Dengkw      0.085862  0.085925 -0.018008    0.189069  ...  0.621782 -0.000119
# cTp_net    -0.171041 -0.141646 -0.238046   -0.181602  ...  0.680974 -0.014796
# DANCE       0.203313  0.220425  0.138983    0.218170  ...  0.659043  0.109855
# Seurat      0.105216  0.196068  0.206410    0.136438  ...  0.720959  0.303986
# Liger      -0.022658  0.034236  0.046307    0.047437  ...  0.394404  0.063927
# BABEL            NaN       NaN -0.005278         NaN  ...  0.695988       NaN
# CMAE        0.132797  0.151310  0.132490    0.014201  ...  0.688974  0.143959
# sciPENN     0.026761  0.084511  0.054569    0.072433  ...  0.847843  0.170945
#
#            CD138_2     CD199    CD45RB      CD99   CLEC12A      CD46  \
# totalVI   0.106153  0.167412  0.375316  0.017789  0.016220 -0.011646
# scArches  0.105377  0.145435  0.325744  0.116304  0.000073 -0.042746
# Dengkw   -0.001365  0.050916  0.316339  0.235506  0.118662  0.226893
# cTp_net   0.192315 -0.013897  0.088207 -0.181269 -0.080912 -0.214553
# DANCE     0.131336  0.212807  0.248370  0.170091  0.064371  0.224777
# Seurat    0.263613  0.248585  0.263892  0.160795  0.261348  0.109150
# Liger     0.044921  0.047166  0.105948  0.155788  0.029048 -0.024724
# BABEL    -0.005675  0.003400  0.199708       NaN       NaN       NaN
# CMAE      0.109803  0.175309  0.198668 -0.035585 -0.041131  0.017328
# sciPENN   0.121717  0.128146  0.373056  0.158690  0.253766  0.082029
#
#             VEGFR3    CLEC1B
# totalVI   0.013755  0.045869
# scArches  0.061594  0.441238
# Dengkw   -0.017955  0.250162
# cTp_net  -0.219355  0.258396
# DANCE     0.104808  0.426804
# Seurat    0.214957  0.297922
# Liger     0.030665       NaN
# BABEL     0.002455       NaN
# CMAE      0.040305  0.436826
# sciPENN   0.038425  0.187405
#
# [10 rows x 210 columns]

# %%
PCCs_cell
# Out:
#           AAACAGCCAACCTGGT-2  CCGCTAGCATAGACTT-2  AAACAGCCAGGTTTGC-2  \
# totalVI             0.980488            0.999620            0.988944
# scArches            0.981197            0.999198            0.727621
# Dengkw              0.917941            0.974850            0.936820
# cTp_net             0.024856            0.013890            0.340221
# DANCE               0.972908            0.999276            0.615339
# Seurat              0.067239            0.240779            0.334605
# Liger               0.703046            0.172599            0.592660
# BABEL               0.976103            0.993794            0.951272
# CMAE                0.976621            0.999595            0.988623
# sciPENN             0.406109            0.475676            0.194394
#
#           GGTAAGGGTCCTGATT-2  GGTAAGGGTTAGGCTA-2  CCGCTTAGTGAATCGC-2  \
# totalVI             0.999115            0.997422            0.995228
# scArches            0.996662            0.997781            0.997106
# Dengkw              0.976848            0.913956            0.985407
# cTp_net             0.020522            0.076057            0.154217
# DANCE               0.998376            0.996471            0.997395
# Seurat              0.255377            0.116649            0.226137
# Liger               0.239051            0.968947            0.746052
# BABEL               0.997819            0.996809            0.993235
# CMAE                0.998990            0.997079            0.997809
# sciPENN             0.510137            0.144581            0.223910
#
#           GGTAATTGTGCTAGAC-2  CCGTGCTGTTAGTGAT-2  AAACGCGCACAATGTT-2  \
# totalVI             0.998094            0.986808            0.980903
# scArches            0.997927            0.981322            0.982953
# Dengkw              0.986867            0.978438            0.955429
# cTp_net             0.406215            0.064558            0.363704
# DANCE               0.968453            0.976787            0.980339
# Seurat              0.450179            0.129969            0.420334
# Liger               0.932060            0.926574            0.864172
# BABEL               0.998173            0.974451            0.960626
# CMAE                0.999030            0.975738            0.960604
# sciPENN             0.327078            0.390643            0.249631
#
#           CCGTTAACACTAGCGT-2  ...  CCCTCACCAGTAGGTG-2  GGGTTACGTGTCCAGG-2  \
# totalVI             0.985202  ...            0.988935            0.999044
# scArches            0.988751  ...            0.985589            0.998972
# Dengkw              0.973539  ...            0.955718            0.968443
# cTp_net             0.074905  ...            0.405432            0.312553
# DANCE               0.973734  ...            0.979713            0.988475
# Seurat              0.143678  ...            0.413267            0.348863
# Liger               0.657776  ...            0.740549            0.991681
# BABEL               0.992390  ...            0.982160            0.999338
# CMAE                0.992731  ...            0.989343            0.999369
# sciPENN             0.201280  ...            0.280440            0.275111
#
#           TTTGTGAAGGATTGAG-2  TTTGTGAAGTTATGGC-2  CCCTCATAGGAAACTG-2  \
# totalVI             0.987041            0.998348            0.998860
# scArches            0.988245            0.998361            0.998196
# Dengkw              0.991041            0.995950            0.925938
# cTp_net             0.412516            0.073393           -0.023311
# DANCE               0.992098            0.994537            0.997578
# Seurat              0.378946            0.115301            0.055191
# Liger               0.699239            0.981201            0.921095
# BABEL               0.992777            0.996527            0.996463
# CMAE                0.980417            0.997547            0.999045
# sciPENN             0.256708            0.366715            0.179089
#
#           CCCTGGACAGTATGTT-2  TTTGTGTTCAACCAAC-2  CCGCAAGGTACCTTAC-2  \
# totalVI             0.997258            0.998893            0.979653
# scArches            0.997127            0.998476            0.979809
# Dengkw              0.995110            0.991111            0.977307
# cTp_net            -0.014541            0.005491            0.095898
# DANCE               0.995453            0.997117            0.973742
# Seurat              0.026333            0.051292            0.221129
# Liger               0.907865            0.985077            0.714379
# BABEL               0.995852            0.998807            0.991144
# CMAE                0.995542            0.998820            0.947174
# sciPENN             0.216296            0.188664            0.174041
#
#           TTTGTTGGTTGGGTTA-2  GGTAAACCAAGTGTTT-2
# totalVI             0.998637            0.999164
# scArches            0.998502            0.999352
# Dengkw              0.991419            0.993245
# cTp_net             0.074877            0.290265
# DANCE               0.993355            0.997812
# Seurat              0.124925            0.279273
# Liger               0.689698            0.363860
# BABEL               0.997213            0.996251
# CMAE                0.998451            0.998996
# sciPENN             0.248180            0.449600
#
# [10 rows x 1228 columns]

# %%
PCCs_protein.to_csv("../Results/new_pictures/"+dataset_num+"/"+ dataset_num +"_pccs_proteins_ten.csv")
PCCs_cell.to_csv("../Results/new_pictures/"+dataset_num+"/"+ dataset_num +"_pccs_cells_ten.csv")

# %%
font = {'family':'DejaVu Sans','weight':'normal','size':15}
plt.figure(figsize=(5,4), dpi= 80)
fig1 = sns.boxplot(data=PCCs_protein.T,orient = "h",linewidth=1,width=0.7, palette="Blues_r",fliersize=0,flierprops = {'marker':'o'})
fig1.set_xlabel("pcc_protein")
fig1.set_xlim(-1.1,1.1)
fig1.spines['top'].set_visible(False)
fig1.spines['right'].set_visible(False)
plt.title(dataset_num, fontdict={'size': 12})
fig1.set_facecolor('white')
# plt.savefig("../Results/tenmethods/"+ dataset_num +"_pccs_proteins_ten.pdf", bbox_inches="tight")
plt.show()

# %%
index = PCCs_protein.index
ax = fig1.axes
lines = ax.get_lines()
categories = ax.get_yticks()
median = []
for cat in categories:
    y = round(lines[4+cat*6].get_xdata()[0],3) 
    median.append(y)
temp = pd.DataFrame(data = median,index = index,columns = ['median'])
temp.sort_values(by='median', inplace=True, ascending=False)
my_order = list(temp.index)

fig1 = sns.boxplot(data=PCCs_protein.T,linewidth=1.5,width=0.5, palette="Blues_r",fliersize=0,flierprops = {'marker':'o'},order = my_order)
fig1.set_xticklabels(temp.index, rotation=90)
plt.title(dataset_num+ "_pccs_proteins")
plt.show()

# %%
font = {'family':'DejaVu Sans','weight':'normal','size':15}
plt.figure(figsize=(5,4), dpi= 80)
fig2 = sns.boxplot(data=PCCs_cell.T,orient = "h",linewidth=1,width=0.7, palette="Blues_r",fliersize=0,flierprops = {'marker':'o'})
fig2.set_xlabel("pcc_cell")
fig2.set_xlim(-1.0,1.1)
fig2.spines['top'].set_visible(False)
fig2.spines['right'].set_visible(False)
plt.title(dataset_num, fontdict={'size': 12})
fig2.set_facecolor('white')
# plt.savefig("../Results/tenmethods/"+ dataset_id +"_pccs_cells.pdf", bbox_inches="tight")
plt.show()

# %%
index = PCCs_cell.index
ax = fig2.axes
lines = ax.get_lines()
categories = ax.get_yticks()
median = []
for cat in categories:
    y = round(lines[4+cat*6].get_xdata()[0],3) 
    median.append(y)
temp = pd.DataFrame(data = median,index = index,columns = ['median'])
temp.sort_values(by='median', inplace=True, ascending=False)
my_order = list(temp.index)

fig2 = sns.boxplot(data=PCCs_cell.T,linewidth=1.5,width=0.5 , whis=0.5, palette="Blues_r",fliersize=0,flierprops = {'marker':'o'},order = my_order)
fig2.set_xticklabels(temp.index, rotation=90,fontsize = 'small')
plt.title(dataset_num +"_pccs_cells")
plt.show()

# %% [markdown]
# ### CMD ###

# %%
List = ['totalVI_pre','scArches_pre','Dengkw_pre','cTp_net_pre','DANCE_pre','Seurat_pre','Liger_pre','BABEL_pre','CMAE_pre','sciPENN_pre']
index = ['totalVI','scArches','Dengkw','cTp_net','DANCE','Seurat','Liger','BABEL','CMAE','sciPENN']

# %%
def CMD_dist(A, B):
    a = np.trace(A.dot(B))
    b = np.linalg.norm(A,'fro')*np.linalg.norm(B,'fro')
    return 1- a/(b+1e-8)

# %%
## 计算cmd_cell
true_corr = true_data.T.corr()
true_corr.dropna(how='all',axis = 1,inplace = True)
true_corr.dropna(how='all',inplace = True)

cmd_cell = []

for i in range(len(List)-1):
    A = eval(List[i]).T.corr()
    A.dropna(how='all',axis = 1,inplace = True)
    A.dropna(how='all',inplace = True)

    B = true_corr
    
    inter_cell = A.index.intersection(B.index)
    B = B[inter_cell]
    B = (B.T)[inter_cell].T
    
    A = A[inter_cell]
    A = (A.T)[inter_cell].T
    
    cmd = CMD_dist(A.values.T,B.values)

    cmd_cell.append(cmd)

sciPENN_cell_cmd = CMD_dist(sciPENN_scale.T.corr().values.T,C.T.corr().values)
cmd_cell.append(sciPENN_cell_cmd)

CMD_cell = pd.DataFrame(data = cmd_cell, index = index,columns = ['cmd_values'])

# %%
#计算cmd_protein
true_protein_corr = true_data.corr()
true_protein_corr.dropna(how='all',axis = 1,inplace = True)
true_protein_corr.dropna(how='all',inplace = True)

cmd_protein = []
for i in range(len(List)-1):
    A = eval(List[i]).corr()
    A.dropna(how='all',axis = 1,inplace = True)
    A.dropna(how='all',inplace = True)

    B = true_protein_corr
    
    inter_cell = A.columns.intersection(B.columns)
    inter_gene = A.index.intersection(B.index)
    B = B[inter_cell]
    B = (B.T)[inter_gene].T
    
    A = (A.T)[inter_gene].T
    A = A[inter_cell]

    cmd = CMD_dist(A.values.T,B.values)

    cmd_protein.append(cmd)

sciPENN_protein_cmd = CMD_dist(sciPENN_scale.corr().values.T,C.corr().values)
cmd_protein.append(sciPENN_protein_cmd)

CMD_protein = pd.DataFrame(data = cmd_protein, index = index,columns = ['cmd_values'])

# %%
CMD_cell.to_csv("../Results/new_pictures/"+dataset_num+"/"+ dataset_num +"_cmd_cells_ten.csv")
CMD_protein.to_csv("../Results/new_pictures/"+dataset_num+"/"+ dataset_num +"_cmd_proteins_ten.csv")

# %%
font = {'family':'DejaVu Sans','weight':'normal','size':15}
plt.figure(figsize=(5,4), dpi= 80)
fig3 = sns.barplot(x = "cmd_values",y = index,orient = "h",data = CMD_cell, ci = 95, palette = "Blues_r")
fig3.set_xlabel("cmd_cell")
fig3.spines['top'].set_visible(False)
fig3.spines['right'].set_visible(False)
fig3.set_xticks(np.arange(0,0.45,0.05))
plt.title(dataset_num, fontdict={'size': 12})
# plt.savefig("../Results/new_pictures/"+dataset_id+"/"+ dataset_id +"_cmd_cells.pdf", bbox_inches="tight")
plt.show()

# %%
font = {'family':'DejaVu Sans','weight':'normal','size':15}
plt.figure(figsize=(5,4), dpi= 80)
fig4 = sns.barplot(x = "cmd_values",y = index,orient = "h",data = CMD_protein, ci = 95, palette = "Blues_r")
fig4.set_xlabel("cmd_protein")
fig4.spines['top'].set_visible(False)
fig4.spines['right'].set_visible(False)
# fig4.set_xlim(0,0.5)
fig4.set_xticks(np.arange(0,0.45,0.05))
plt.title(dataset_num, fontdict={'size': 12})
# plt.savefig("../Results/new_pictures/"+dataset_id+"/"+ dataset_id +"_cmd_proteins.pdf", bbox_inches="tight")
plt.show()

# %% [markdown]
# ### 绘制图像

# %%
index_new = ['totalVI','scArches','Dengkw','DANCE','CMAE','BABEL','Seurat','Liger','cTp_net','sciPENN']

# %%
PCCs_protein = PCCs_protein.T[index_new].T
PCCs_cell = PCCs_cell.T[index_new].T

CMD_cell = CMD_cell.T[index_new].T
CMD_protein = CMD_protein.T[index_new].T

# %%
my_pal = {'totalVI':'#E6D885','scArches':'#F1C67F','Dengkw':'#E7A365','DANCE':'#EE9185','CMAE':'#E2A6C0','BABEL':'#BEABCB','Seurat':'#7DC9C4','sciPENN':'#84a4e8','Liger':'#65AADD','cTp_net':'#7CC38A'}

# %%
plt.figure(figsize=(18,3), dpi= 80)

ax1 = plt.subplot(141)
ax1 = sns.boxplot(data=PCCs_protein.T,orient = "h",linewidth=1,width=0.7, palette=my_pal,fliersize=0,flierprops = {'marker':'o'})
ax1.set_xlabel("pcc_protein")
ax1.set_xlim(-1.1,1.1)
ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)

ax2 = plt.subplot(142)
ax2 = sns.boxplot(data=PCCs_cell.T,orient = "h",linewidth=1,width=0.7, palette=my_pal,fliersize=0,flierprops = {'marker':'o'})
ax2.set_xlabel("pcc_cell")
ax2.set_xlim(-1.1,1.1)
ax2.spines['top'].set_visible(False)
ax2.spines['right'].set_visible(False)
plt.yticks(alpha=0)

ax3 = plt.subplot(143)
ax3 = sns.barplot(x = "cmd_values",y = CMD_cell.index,orient = "h",data = CMD_cell, ci = 95, palette = my_pal)
ax3.set_xlabel("cmd_cell")
ax3.spines['top'].set_visible(False)
ax3.spines['right'].set_visible(False)
ax3.set_xticks(np.arange(0,0.55,0.1))
plt.yticks(alpha=0)

ax4 = plt.subplot(144)
ax4 = sns.barplot(x = "cmd_values",y = CMD_protein.index,orient = "h",data = CMD_protein, ci = 95, palette = my_pal)
ax4.set_xlabel("cmd_protein")
ax4.spines['top'].set_visible(False)
ax4.spines['right'].set_visible(False)
ax4.set_xticks(np.arange(0,0.55,0.1))
plt.yticks(alpha=0)

# plt.savefig("../Results/new_pictures/one_per/dataset"+ dataset_num +"_tenmethods.pdf", bbox_inches="tight")
plt.show()
